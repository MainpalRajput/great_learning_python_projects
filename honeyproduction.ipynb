# %% [markdown]
# ## 1. Import required libraries and read the dataset.

# %%
try:
    import numpy as np 
    import pandas as pd 
    import seaborn as sns
    import matplotlib.pyplot as plt
    import warnings
    warnings.filterwarnings("ignore")
    DeprecationWarning("ignore")
except FileNotFoundError as err:
    print(err__name__)

# %%
#function for read file
def read_file(file_loca,file_name):
    try:
        return pd.read_csv(file_loca+"/"+file_name)
    except:
        raise FileNotFoundError

# %%
file_loca="E:/project"
file_name="honeyproduction.csv"
df=read_file(file_loca,file_name)
df
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %% [markdown]
# ## 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
#first five rows
df.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
#last five rows
df.tail()
# Out:
#     state   numcol  yieldpercol  totalprod     stocks  priceperlb  prodvalue  \
# 621    VA   4000.0           41   164000.0    23000.0        3.77   618000.0
# 622    WA  62000.0           41  2542000.0  1017000.0        2.38  6050000.0
# 623    WV   6000.0           48   288000.0    95000.0        2.91   838000.0
# 624    WI  60000.0           69  4140000.0  1863000.0        2.05  8487000.0
# 625    WY  50000.0           51  2550000.0   459000.0        1.87  4769000.0
#
#      year
# 621  2012
# 622  2012
# 623  2012
# 624  2012
# 625  2012

# %%
#shape of the data
df.shape
# Out:
# (626, 8)

# %%
#check info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.2+ KB

# %%
#check null values
df.isnull().sum()
# Out:
# state          0
# numcol         0
# yieldpercol    0
# totalprod      0
# stocks         0
# priceperlb     0
# prodvalue      0
# year           0
# dtype: int64

# %%
#check the columns
df.columns
# Out:
# Index(['state', 'numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb',
#        'prodvalue', 'year'],
#       dtype='object')

# %% [markdown]
# ## 3. Display the percentage distribution of the data in each year using the pie chart.

# %%
#percentage distribution of the data in each year using pie chart
plt.figure(figsize= (12,9))        
df["year"].value_counts().plot(kind = 'pie',autopct =" %1.2f%%")
plt.title('Percentage Distribution for year')
plt.show()

# %% [markdown]
#  the code efficiently produces a well-labeled pie chart that visually conveys the percentage distribution of data among various years. The use of Pandas for data manipulation and Matplotlib for visualization makes the process streamlined, resulting in a clear representation of the data's temporal distribution.

# %% [markdown]
# ## 4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
df.head(1)
# Out:
#   state   numcol  yieldpercol  totalprod    stocks  priceperlb  prodvalue  \
# 0    AL  16000.0           71  1136000.0  159000.0        0.72   818000.0
#
#    year
# 0  1998

# %%
#plot displot using seaborn 
sns.displot(df["priceperlb"],kde=True)
plt.show()

# %% [markdown]
#  The given code snippet uses the Seaborn library to create a distribution plot that visualizes the distribution of values in the "priceperlb" column of the DataFrame. This plot combines a histogram and a smoothed curve known as a kernel density estimate (KDE). the distribution of "pricelb" is right skewed.

# %% [markdown]
# ## 5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings.

# %%
#plot scatterplot using seaborn
sns.scatterplot(x=df["numcol"],y=df["prodvalue"])
plt.show()

# %% [markdown]
# The provided code snippet generates a scatterplot that visually represents the relationship between the 'numcol' and 'prodvalue' variables from the DataFrame. Scatterplots are particularly useful for understanding the correlation and distribution of two continuous variables

# %%
sns.regplot(x=df["numcol"],y=df["prodvalue"])
plt.show()

# %% [markdown]
# the provided code generates a scatterplot with a linear regression line, offering valuable insights into the correlation between the 'numcol' and 'prodvalue' variables.some outliers are also present.

# %% [markdown]
# ## 6. Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot, and write your findings

# %%
#plot boxplot using seaborn
plt.figure(figsize=(15,8))
sns.boxplot(df,x="year",y="prodvalue")
plt.show()

# %% [markdown]
# By examining the box plot, you can identify differences in production value distributions across different years. You can observe whether there are any significant variations or trends in production values for each year. This visualization helps you quickly grasp how the production values are distributed and whether there are any potential anomalies or patterns.we can see that outlier present in all years.

# %% [markdown]
# ## 7. Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
plt.figure(figsize=(20,10))
sns.pairplot(df,vars=["numcol","yieldpercol","totalprod","prodvalue","year"])
plt.show()

# %% [markdown]
# By examining the scatterplots in the pair plot matrix, you can quickly gain insights into how these variables interact

# %% [markdown]
# ## 8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'stocks', 'price per lb', 'prodvalue')

# %%
df[["numcol" ,"prodvalue" ,"yieldpercol" ,"totalprod" , "stocks" ,"priceperlb"]].corr()
# Out:
#                numcol  prodvalue  yieldpercol  totalprod    stocks  priceperlb
# numcol       1.000000   0.912796     0.243515   0.953594  0.825929   -0.232701
# prodvalue    0.912796   1.000000     0.278977   0.907236  0.728560   -0.089567
# yieldpercol  0.243515   0.278977     1.000000   0.396252  0.367812   -0.358646
# totalprod    0.953594   0.907236     0.396252   1.000000  0.878830   -0.264499
# stocks       0.825929   0.728560     0.367812   0.878830  1.000000   -0.305867
# priceperlb  -0.232701  -0.089567    -0.358646  -0.264499 -0.305867    1.000000

# %%
#plot haeatmap using seaborn
sns.heatmap(df[["numcol" ,"prodvalue" ,"yieldpercol" ,"totalprod" , "stocks" ,"priceperlb"]].corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# The provided code snippet generates a heatmap that visually represents the correlation matrix between the selected variables: 'numcol', 'prodvalue', 'yieldpercol', 'totalprod', 'stocks', and 'priceperlb'. The heatmap provides a visual way to assess the strength and direction of linear relationships between these variables.correlation between "totlprod" and "numcol" is maximum i.e 0.95
# "priceperlb" shows negative relation to all other
